# %% [markdown]
# # Inventaire initial du dataset — Online Retail II

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

from src.load_data import charger_ventes_en_ligne

donnees = charger_ventes_en_ligne()
donnees.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1     489434     79323P                   PINK CHERRY LIGHTS        12
# 2     489434     79323W                  WHITE CHERRY LIGHTS        12
# 3     489434      22041         RECORD FRAME 7" SINGLE SIZE         48
# 4     489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#          invoice_date  unit_price  customer_id         country
# 0 2009-12-01 07:45:00        6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00        6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00        6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00        2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00        1.25      13085.0  United Kingdom

# %% [markdown]
# ## Dimensions et types

# %%
print("Lignes :", donnees.shape[0])
print("Colonnes :", donnees.shape[1])
donnees.dtypes
# Out:
# Lignes : 1067371
# Colonnes : 8
# invoice_no                 str
# stock_code                 str
# description                str
# quantity                 int64
# invoice_date    datetime64[us]
# unit_price             float64
# customer_id            float64
# country                    str
# dtype: object

# %% [markdown]
# ## Période couverte

# %%
print("Du :", donnees["invoice_date"].min())
print("Au :", donnees["invoice_date"].max())
# Out:
# Du : 2009-12-01 07:45:00
# Au : 2011-12-09 12:50:00

# %% [markdown]
# ## Valeurs manquantes

# %%
donnees.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       4382
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     243007
# country              0
# dtype: int64

# %% [markdown]
# ## Doublons exacts

# %%
donnees.duplicated().sum()
# Out:
# np.int64(34335)

# %% [markdown]
# ## Prix nuls ou négatifs

# %%
donnees[donnees["unit_price"] <= 0].shape[0]
# Out:
# 6207

# %% [markdown]
# ## Quantités négatives

# %%
donnees[donnees["quantity"] < 0].shape[0]
# Out:
# 22950

# %% [markdown]
# ## Factures annulées (commençant par "C")

# %%
factures_annulees = donnees["invoice_no"].astype(str).str.startswith("C")
factures_annulees.sum()
# Out:
# np.int64(19494)

# %% [markdown]
# ## Cardinalités (clients, produits, pays)

# %%
print("Clients uniques :", donnees["customer_id"].nunique())
print("Produits uniques :", donnees["stock_code"].nunique())
print("Pays uniques :", donnees["country"].nunique())
# Out:
# Clients uniques : 5942
# Produits uniques : 5305
# Pays uniques : 43
